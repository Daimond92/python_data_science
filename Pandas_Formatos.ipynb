# %% [markdown]
# <a href="https://colab.research.google.com/github/Daimond92/python_data_science/blob/develop/Pandas_Formatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importaciones

# %%
import pandas as pd

# %% [markdown]
# # Archivos CSV

# %% [markdown]
# ## Importando archivo CSV

# %% [markdown]
# Se deben importar los archivos de la carpeta [Data](https://github.com/Daimond92/python_data_science/tree/develop/Data)
#
# - datos_sus.csv
# - superstore_data.csv
# - superstore_data_punto_coma.csv

# %%
datos = pd.read_csv('superstore_data.csv')

# %%
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# ### Parametros de la función read_csv

# %% [markdown]
# [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
datos_separador = pd.read_csv('superstore_data_punto_coma.csv', sep = ';')

# %%
datos_separador.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
datos_primeras_filas = pd.read_csv('superstore_data.csv', nrows = 5)

# %%
datos_primeras_filas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
datos_seleccion_columnas = pd.read_csv('superstore_data.csv', usecols = ['Id', 'Year_Birth', 'Income'])

# %%
datos_seleccion_columnas
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
datos_seleccion_columnas_posicion = pd.read_csv('superstore_data.csv', usecols = [0, 1, 4])

# %%
datos_seleccion_columnas_posicion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## Exportar archivo csv

# %% [markdown]
# [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)

# %%
datos_seleccion_columnas_posicion.to_csv('clientes_mercado.csv', index = False)

# %%
clientes_mercado = pd.read_csv('clientes_mercado.csv')
clientes_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# # Archivos en excel

# %% [markdown]
# ## Importanto archivos xls

# %% [markdown]
# Se deben importar los archivos de la carpeta [Data](https://github.com/Daimond92/python_data_science/tree/develop/Data)
#
# - emisiones_CO2.xlsx

# %%
archivo = 'emisiones_CO2.xlsx'

# %%
datos_co2 = pd.read_excel(archivo)

# %%
datos_co2.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %% [markdown]
# ### Parametros de la función read_excel

# %% [markdown]
# [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html)

# %% [markdown]
# #### Consultar nombre de hojas de calculo

# %%
pd.ExcelFile(archivo).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %%
percapita = pd.read_excel(archivo, sheet_name = 'emisiones_percapita')

# %%
percapita.sample(5)
# Out:
#                        País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  \
# 15572  República Dominicana                DOM  1818    NaN     NaN     NaN
# 28850                Kosovo                KSV  1768    NaN     NaN     NaN
# 51469         Islas Salomón                SLB  1811    NaN     NaN     NaN
# 45809              Moldavia                MDA  1863    NaN     NaN     NaN
# 1713              Antártida                ATA  1831    NaN     NaN     NaN
#
#        Gas  Cemento  Quema  Otros
# 15572  NaN      NaN    NaN    NaN
# 28850  NaN      NaN    NaN    NaN
# 51469  NaN      NaN    NaN    NaN
# 45809  NaN      NaN    NaN    NaN
# 1713   NaN      NaN    NaN    NaN

# %%
fuentes = pd.read_excel(archivo, sheet_name = 'fuentes')

# %%
fuentes.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
# ...

# %% [markdown]
# #### Escoger columnas y filas del archivo - Generar intervalos

# %%
intervalo = pd.read_excel(archivo, sheet_name = 'emisiones_C02', usecols = 'A:D')

# %%
intervalo
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
intervalo2 = pd.read_excel(archivo, sheet_name = 'emisiones_C02', usecols = 'A:D', nrows=10)

# %%
intervalo2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ## Exportar archivo excel

# %%
intervalo.to_excel('co2_percapita.xlsx', index = False)

# %%
pd.read_excel('co2_percapita.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# ## Importar archivos de google sheets

# %% [markdown]
# Se deben importar en una hoja de [google sheets](https://workspace.google.com/intl/es/products/sheets/) el archivo de la carpeta [Data](https://github.com/Daimond92/python_data_science/tree/develop/Data)
#
# - emisiones_CO2.xlsx

# %% [markdown]
# Link: https://docs.google.com/spreadsheets/d/1zSWzXyUGFdmseNopk9Y20-nOANF0UkFyU0ZhYQJ2U_g/edit?usp=sharing

# %%
sheet_id = '1zSWzXyUGFdmseNopk9Y20-nOANF0UkFyU0ZhYQJ2U_g'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos_co2 = pd.read_csv(url)

# %%
datos_co2
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36.096.739.276  14.506.973.805
# 63100      Global                WLD  2018  36.826.506.600  14.746.830.688
# 63101      Global                WLD  2019  37.082.558.969  14.725.978.025
# 63102      Global                WLD  2020  35.264.085.734  14.174.564.010
# 63103      Global                WLD  2021  37.123.850.352  14.979.598.083
#
# ...

# %%
sheet_id = '1zSWzXyUGFdmseNopk9Y20-nOANF0UkFyU0ZhYQJ2U_g'
sheet_name = 'emisiones_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
datos_percapita = pd.read_csv(url_percapita)

# %%
datos_percapita
# Out:
#              País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 0      Afganistán                AFG  1750        NaN        NaN        NaN
# 1      Afganistán                AFG  1751        NaN        NaN        NaN
# 2      Afganistán                AFG  1752        NaN        NaN        NaN
# 3      Afganistán                AFG  1753        NaN        NaN        NaN
# 4      Afganistán                AFG  1754        NaN        NaN        NaN
# ...           ...                ...   ...        ...        ...        ...
# 63099      Global                WLD  2017  4.749.682  1.908.857  1.610.910
# 63100      Global                WLD  2018  4.792.753  1.919.213  1.596.350
# 63101      Global                WLD  2019  4.775.633  1.896.468  1.589.920
# 63102      Global                WLD  2020  4.497.423  1.807.760  1.427.353
# 63103      Global                WLD  2021  4.693.699  1.893.923  1.496.614
#
#              Gas  Cemento   Quema   Otros
# ...

# %%
sheet_id = '1zSWzXyUGFdmseNopk9Y20-nOANF0UkFyU0ZhYQJ2U_g'
sheet_name = 'fuentes'
url_fuentes = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
datos_fuentes = pd.read_csv(url_fuentes)

# %%
datos_fuentes.head()
# Out:
#          País ISO 3166-1 alpha-3   Año   Total  Carbón  Aceite     Gas  \
# 0  Afganistán                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afganistán                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afganistán                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afganistán                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afganistán                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cemento   Quema   Otros Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %% [markdown]
# # Archivos json

# %% [markdown]
# ## Importando archivos json

# %% [markdown]
# Se deben importar los archivos de la carpeta [Data](https://github.com/Daimond92/python_data_science/tree/develop/Data)
#
# - pacientes.json
# - pacientes_2.json

# %% [markdown]
# ### Diccionario normal en un archivo json

# %% [markdown]
# Para ver de forma visual un archivo json se puede utilizar el siguiente link:
# - [jsonviewer](https://jsonviewer.stack.hu/)
#
# [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.read_json.html)

# %%
datos_pacientes = pd.read_json('pacientes.json')

# %%
datos_pacientes
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# ...

# %% [markdown]
# ### Diccionario dentro del diccionario en un archivo json

# %% [markdown]
# Para ver la estructura de un archivo json se puede utilizar el siguiente editor:
# - [jsoncrack](https://jsoncrack.com/editor)

# %%
datos_pacientes2 = pd.read_json('pacientes_2.json')

# %%
datos_pacientes2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %% [markdown]
# #### Normalizando archivo json

# %%
df_normalizado = pd.json_normalize(datos_pacientes2['Pacientes'])

# %%
df_normalizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ### Obtener json de APIS

# %% [markdown]
# Se debe seguir el siguiente proceso:
# - Acceder al API, para este caso es [Fruitvice](https://fruityvice.com/)
# - importar requests y json
# - Obtener url
# - Adiciona al final api/fruit/all
# - Obtener los resultados mediante el metodo loads()
# - Obtener vista de DataFrame

# %%
import requests
import json

# %%
datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')

# %%
frutas = json.loads(datos_frutas.text)

# %%
pd.DataFrame(frutas)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
frutas
# Out:
# [{'name': 'Persimmon',
#   'id': 52,
#   'family': 'Ebenaceae',
#   'order': 'Rosales',
#   'genus': 'Diospyros',
#   'nutritions': {'calories': 81,
#    'fat': 0.0,
#    'sugar': 18.0,
#    'carbohydrates': 18.0,
#    'protein': 0.0}},
#  {'name': 'Strawberry',
#   'id': 3,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'genus': 'Fragaria',
#   'nutritions': {'calories': 29,
#    'fat': 0.4,
#    'sugar': 5.4,
#    'carbohydrates': 5.5,
#    'protein': 0.8}},
#  {'name': 'Banana',
#   'id': 1,
#   'family': 'Musaceae',
#   'order': 'Zingiberales',
#   'genus': 'Musa',
#   'nutritions': {'calories': 96,
#    'fat': 0.2,
#    'sugar': 17.2,
#    'carbohydrates': 22.0,
#    'protein': 1.0}},
#  {'name': 'Tomato',
#   'id': 5,
#   'family': 'Solanaceae',
#   'order': 'Solanales',
#   'genus': 'Solanum',
#   'nutritions': {'calories': 74,
#    'fat': 0.2,
#    'sugar': 2.6,
#    'carbohydrates': 3.9,
#    'protein': 0.9}},
#  {'name': 'Pear',
#   'id': 4,
# ...

# %% [markdown]
# ## Exportar archivo json

# %%
df_normalizado.to_json('pacientes_normalizados.json')

# %%
lectura_json = pd.read_json('pacientes_normalizados.json')

# %%
lectura_json
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0   1      55-59          Mujer  Blanca  16.60      Sí              No
# 1   2     80 ó +          Mujer  Blanca  20.34      No              No
# 2   3      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# # Ejercicios

# %% [markdown]
# ## Primera parte

# %%
datos_clinica = pd.read_csv('datos_sus.csv', sep = ';', encoding = 'ISO-8859-1', skiprows=range(3), skipfooter=9, engine='python')

# %%
datos_clinica
# Out:
#    Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia    1388528,39    2931283,42    1541682,52
# 1                  Acre     902416,00    1497206,26    1794028,48
# 2              Amazonas    4735529,42    7118990,57    8196635,49
# 3               Roraima     657889,53     777939,31     718688,03
# 4                  Pará   18864744,11   19553758,20   21937342,70
# 5                 Amapá    1120973,34    1268740,33     974651,24
# 6             Tocantins    3441592,69    4985688,85    6205612,60
# 7              Maranhão   10723506,39   13559679,41   13985142,36
# 8                 Piauí    7985142,43   10079928,25   10298372,45
# 9                 Ceará   15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte    5947814,08    9509755,83   10352238,59
# 11              Paraíba   10723002,45   11386274,47   12053643,87
# 12           Pernambuco   14393949,89   24181400,95   29991302,71
# ...

# %% [markdown]
# ## Segunda parte

# %% [markdown]
# Se deben importar en una hoja de google sheets el archivo de la carpeta [Data](https://github.com/Daimond92/python_data_science/tree/develop/Data)
#
# - emisiones_carbono_mundo.xlsx

# %% [markdown]
# Link: https://docs.google.com/spreadsheets/d/1Yjc7m5zKXhAcoYHjIOCTsLn42Z_EpkwQHElvU5uoleo/edit?usp=sharing

# %%
sheet_id_ejecicio = '1Yjc7m5zKXhAcoYHjIOCTsLn42Z_EpkwQHElvU5uoleo'
url_ejecicio = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
emisiones_carbono_mundo = pd.read_csv(url_ejecicio)

# %%
emisiones_carbono_mundo.sample(5)
# Out:
#                     País ISO 3166-1 alpha-3   Año      Total   Carbón  \
# 39772          Nicaragua                NIC  1810          0      NaN
# 8014   Brunei Darussalam                BRN  1876          0      NaN
# 38877              Nepal                NPL  2003  2.810.383  663.184
# 22298        Groenlandia                GRL  2016    524.924        0
# 29682         Kirguistán                KGZ  1784          0      NaN
#
#           Aceite  Gas  Cemento Quema Otros Per Capita
# 39772        NaN  NaN      NaN   NaN   NaN        NaN
# 8014         NaN  NaN        0   NaN   NaN        NaN
# 38877  2.029.856    0  117.343     0   NaN    109.426
# 22298    524.924    0        0     0   NaN  9.387.726
# 29682        NaN  NaN      NaN   NaN   NaN        NaN

# %%
emisiones_carbono_mundo.to_csv('emisiones_carbono_mundo.csv', index=False)

# %%
pd.read_csv('emisiones_carbono_mundo.csv')
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36.096.739.276  14.506.973.805
# 63100      Global                WLD  2018  36.826.506.600  14.746.830.688
# 63101      Global                WLD  2019  37.082.558.969  14.725.978.025
# 63102      Global                WLD  2020  35.264.085.734  14.174.564.010
# 63103      Global                WLD  2021  37.123.850.352  14.979.598.083
#
# ...

# %% [markdown]
# ## Tercera parte

# %% [markdown]
# Del DataFrame frutas, obtenido en la sección Obtener json de APIS, se debe normalizar.

# %%
df_frutas = pd.json_normalize(
    frutas,
    sep='.',  # Para usar un punto como separador entre las claves
    meta=['name', 'id', 'family', 'order', 'genus'],  # Incluye las columnas generales
    record_prefix='nutritions.'  # Esto es para añadir un prefijo a las columnas nutricionales
)

# %%
df_frutas
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...
